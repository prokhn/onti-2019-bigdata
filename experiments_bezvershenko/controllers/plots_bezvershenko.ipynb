# %%
import pandas as pd
import seaborn

# %%
data = pd.read_csv('after_tune.csv', delimiter=';')
data_before = pd.read_csv('before_tune.csv', delimiter=';')

# %%
data.head(15)
# Out:
#    name_model  seed         1       100       200       300       400  \
# 0         pid     0 -0.695815 -0.294583 -0.037962 -0.027551 -0.024451
# 1         pid     1 -0.420515 -0.037809 -0.018252 -0.016062 -0.010439
# 2         pid     2 -0.413291 -0.036447 -0.031187 -0.017052 -0.013217
# 3         pid     3 -0.470858 -0.034504 -0.029788 -0.014474 -0.009593
# 4         pid     4 -0.396022 -0.050929 -0.009419 -0.007983 -0.019135
# 5         pid     5 -0.503032 -0.109462 -0.025315 -0.022611 -0.026337
# 6         pid     6 -0.459109 -0.136083 -0.016150 -0.034667 -0.012042
# 7         pid     7 -0.498173 -0.145179 -0.023111 -0.018042 -0.020111
# 8         pid     8 -0.325314 -0.048547 -0.019035 -0.002485 -0.017182
# 9         pid     9 -0.235808 -0.040208 -0.008835 -0.010803 -0.009648
# 10        pid    10 -0.531990 -0.134137 -0.030683 -0.011967 -0.011506
# 11        pid    11 -0.380543 -0.051859 -0.019893 -0.014165 -0.007779
# 12        pid    12 -0.124916 -0.013482 -0.005706 -0.012501 -0.003323
# 13        pid    13 -0.290444 -0.048098 -0.008469 -0.021016 -0.002623
# 14        pid    14 -0.597408 -0.088642 -0.033441 -0.015276 -0.016811
#
#          500       600       700       800       900      1000  sum_rewards  \
# 0  -0.006726 -0.029993 -0.030447 -0.032600 -0.032610 -0.024304   -83.947630
# 1  -0.011487 -0.009153 -0.003586 -0.011672 -0.009945 -0.016982   -34.295930
# 2  -0.010763 -0.015534 -0.023576 -0.022958 -0.023764 -0.025895   -37.961476
# 3  -0.017111 -0.021312 -0.019624 -0.014024 -0.023741 -0.012430   -45.366310
# 4  -0.008952 -0.019672 -0.011239 -0.012014 -0.006412 -0.015268   -39.522887
# 5  -0.018632 -0.019342 -0.022912 -0.013514 -0.024391 -0.013311   -48.508851
# 6  -0.011878 -0.016044 -0.022397 -0.037732 -0.035668 -0.038757   -55.925963
# 7  -0.014859 -0.025309 -0.021095 -0.016286 -0.021906 -0.011896   -54.058264
# 8  -0.021216 -0.011252 -0.023041 -0.017540 -0.010533 -0.012239   -31.372195
# 9  -0.003714 -0.012295 -0.006204 -0.011299 -0.019505 -0.010679   -22.051916
# 10 -0.010811 -0.024627 -0.014305 -0.019572 -0.020151 -0.013940   -50.697991
# 11 -0.014330 -0.007602 -0.014682 -0.012535 -0.003915 -0.009846   -41.283243
# 12 -0.007798 -0.010433 -0.008533 -0.007905 -0.004076 -0.010660   -12.479734
# 13 -0.021329 -0.010888 -0.023402 -0.004027 -0.024691 -0.015734   -33.275302
# 14 -0.014168 -0.011037 -0.017541 -0.016076 -0.015213 -0.017082   -55.995620
#
#     mean_rewards
# 0      -0.083948
# 1      -0.034296
# 2      -0.037961
# 3      -0.045366
# 4      -0.039523
# 5      -0.048509
# 6      -0.055926
# 7      -0.054058
# 8      -0.031372
# 9      -0.022052
# 10     -0.050698
# 11     -0.041283
# 12     -0.012480
# 13     -0.033275
# 14     -0.055996

# %%
import matplotlib.pyplot as plt

f, ax = plt.subplots(figsize=(15, 10))

ax.plot(data_before['seed'], data_before['mean_rewards'], 'b')
ax.plot(data['seed'], data['mean_rewards'], 'r')

# data.plot(x="seed",y="mean_rewards", figsize=(15, 10))
# data_before.plot(x="seed",y="mean_rewards", figsize=(15, 10))

# %%
for row in data[:10].iterrows():
    a = row[1].drop(['seed', 'name_model', 'sum_rewards', 'mean_rewards'])
    a.plot()

# %%
data2 = pd.read_csv('new.csv', delimiter=';')
data2['mean_rewards'].plot(figsize=(15, 10))
