# %%
import pandas as pd
import seaborn

# %%
data = pd.read_csv('statistic.csv', delimiter=';')

# %%
data.head()
# Out:
#   name_model  seed         1       100       200       300       400  \
# 0        pid     1 -0.420515 -0.135170 -0.043762 -0.050454 -0.027265
# 1        pid     2 -0.413291 -0.016734 -0.014463 -0.005447 -0.006034
# 2        pid     3 -0.470858 -0.154398 -0.083275 -0.046140 -0.033556
# 3        pid     4 -0.396022 -0.090020 -0.035440 -0.018596 -0.011988
# 4        pid     5 -0.503032 -0.078335 -0.019635 -0.011666 -0.012465
#
#         500       600       700       800       900      1000  sum_rewards  \
# 0 -0.015453 -0.011310 -0.010021 -0.003868 -0.003944 -0.005016   -50.859285
# 1 -0.002064 -0.006541 -0.003296 -0.005540 -0.003142 -0.005709   -28.345105
# 2 -0.017652 -0.008251 -0.008344 -0.004190 -0.002622 -0.005100   -59.374312
# 3 -0.011411 -0.009399 -0.005538 -0.003552 -0.002343 -0.007254   -43.018097
# 4 -0.012135 -0.004366 -0.006778 -0.006221 -0.002095 -0.002536   -39.395212
#
#    mean_rewards
# 0     -0.050859
# 1     -0.028345
# 2     -0.059374
# 3     -0.043018
# 4     -0.039395

# %%
data['mean_rewards'].plot()

# %%
for row in data[:10].iterrows():
    a = row[1].drop(['seed', 'name_model', 'sum_rewards', 'mean_rewards'])
    a.plot()
