# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

rewards = np.load('rewards.npy')

# %%
plt.figure(figsize=(15,10))
plt.hist(rewards,  orientation='horizontal')
# Out:
# (array([2.9000e+01, 1.8300e+02, 4.1300e+02, 7.7300e+02, 1.1290e+03,
#         1.5910e+03, 1.7690e+03, 2.4580e+03, 3.6840e+03, 4.7971e+04]),
#  array([-8.56870561e-01, -7.71223597e-01, -6.85576634e-01, -5.99929670e-01,
#         -5.14282706e-01, -4.28635742e-01, -3.42988779e-01, -2.57341815e-01,
#         -1.71694851e-01, -8.60478874e-02, -4.00923643e-04]),
#  <a list of 10 Patch objects>)

# %%
rewards.mean()
# Out:
# -0.07205526115196201

# %%
sns.kdeplot(rewards, shade=True);
